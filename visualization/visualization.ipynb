# %%
import matplotlib.pyplot as plt

# Data grouped by category
data = {
    "Each cluster alone": {
        "min_0": 0.8113009136729484,
        "min_1": 0.9698671614621501,
        "min_2": 0.7105910476658028,
        "informative_cluster_0": 0.9175618982150164,
        "informative_cluster_1": 0.9839455171971598,
    },
    "Each class together": {
        "df_min": 0.8868432187994814,
        "df_majority": 0.994517328976503,
    },
    "Everything together": {
        "everything_together": 0.9978094711364953,
    },
    "Mixed clusters": {
        "min_0_informative_cluster_0": 0.8146360385316167,
        "min_0_informative_cluster_1": 0.948328853115306,
        "min_1_informative_cluster_1": 0.955977572111264,
        "min_1_informative_cluster_0": 0.8447380375163316,
        "min_2_informative_cluster_0": 0.9657846559884142,
        "min_2_informative_cluster_1": 0.9439824471270863,
        "min_0_min_1_informative_cluster_0_informative_cluster_1": 0.9999496787943054,
        "min_0_min_2_informative_cluster_0_informative_cluster_1": 0.9079373887842288,
        "min_1_min_2_informative_cluster_0_informative_cluster_1": 0.9663731874677317
    }
}

# Define colors for each group
colors = {
    "Each cluster alone": "royalblue",
    "Each class together": "green",
    "Everything together": "black",
    "Mixed clusters": "orange"
}

# Plotting
plt.figure(figsize=(14, 6))
x_pos = 0
xticks = []
xticklabels = []

for group, values in data.items():
    xs = list(range(x_pos, x_pos + len(values)))
    ys = list(values.values())

    # Scatter and line
    plt.scatter(xs, ys, label=group, color=colors[group], s=60)
    plt.plot(xs, ys, color=colors[group], linestyle='-', alpha=0.6)  # Line within group

    # X-axis labels
    xticks.extend(xs)
    xticklabels.extend(values.keys())
    x_pos += len(values)

plt.xticks(xticks, xticklabels, rotation=90)
plt.ylabel("CorrelationSimilarity")
plt.title("Scatter Plot of Correlation Similarity by Cluster Groups")
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(0, 1.2)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data grouped by category
data = {
    "Each cluster alone": {
        "min_0": 0.8975474083438686,
        "min_1": 0.8144720020455127,
        "min_2": 0.7682997118155619,
        "informative_cluster_0": 0.8206978119455943,
        "informative_cluster_1": 0.8075280381010908,
    },
    "Everything together": {
        "everything_together": 0.7291780905379882,
    },
    "Each class together": {
        "df_min": 0.776914647510045,
        "df_majority": 0.7889268292682926,
    },
    "Mixed clusters": {
        "min_0_informative_cluster_0": 0.8240524264966348,
        "min_0_informative_cluster_1": 0.7474006116207951,
        "min_1_informative_cluster_1": 0.7785604606525912,
        "min_1_informative_cluster_0": 0.7233131024634059,
        "min_2_informative_cluster_0": 0.8212953876349364,
        "min_2_informative_cluster_1": 0.7498833138856476,
        "min_0_min_1_informative_cluster_0_informative_cluster_1": 0.7514751649446035,
        "min_0_min_2_informative_cluster_0_informative_cluster_1": 0.7703407454807231,
        "min_1_min_2_informative_cluster_0_informative_cluster_1": None  # value missing
    }
}


# Define colors for each group
colors = {
    "Each cluster alone": "royalblue",
    "Each class together": "green",
    "Everything together": "black",
    "Mixed clusters": "orange"
}

# Plotting
plt.figure(figsize=(14, 6))
x_pos = 0
xticks = []
xticklabels = []

for group, values in data.items():
    xs = list(range(x_pos, x_pos + len(values)))
    ys = list(values.values())

    # Scatter and line
    plt.scatter(xs, ys, label=group, color=colors[group], s=60)
    plt.plot(xs, ys, color=colors[group], linestyle='-', alpha=0.6)  # Line within group

    # X-axis labels
    xticks.extend(xs)
    xticklabels.extend(values.keys())
    x_pos += len(values)

plt.xticks(xticks, xticklabels, rotation=90)
plt.ylabel("CorrelationSimilarity")
plt.title("Scatter Plot of Correlation Similarity by Cluster Groups")
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(0.7, 1.02)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data grouped by category
data = {
    "Each cluster alone": {
        "min_0": 0.9922191372650104,
        "min_1": 0.9824744591102442,
        "min_2": 0.9559424494931468,
        "informative_cluster_0": 0.9776029461607519,
        "informative_cluster_1": 0.9752706893874301,
    },
    "Everything together": {
        "everything_together": 0.9954317250008998,
    },
    "Each class together": {
        "df_min": 0.989564185181751,
        "df_majority": 0.9939953072188615,
    },
    "Mixed clusters": {
        "min_0_informative_cluster_0": 0.9913584924703223,
        "min_0_informative_cluster_1": 0.9892459611000692,
        "min_1_informative_cluster_1": 0.9902567033509811,
        "min_1_informative_cluster_0": 0.9786089131459846,
        "min_2_informative_cluster_0": 0.9852325596967788,
        "min_2_informative_cluster_1": 0.9875992281449637,
        "min_0_min_1_informative_cluster_0_informative_cluster_1": 0.9896176647257814,
        "min_0_min_2_informative_cluster_0_informative_cluster_1": 0.9889704687903145,
        "min_1_min_2_informative_cluster_0_informative_cluster_1": 0.9892582002552782
    }
}


# Define colors for each group
colors = {
    "Each cluster alone": "royalblue",
    "Each class together": "green",
    "Everything together": "black",
    "Mixed clusters": "orange"
}

# Plotting
plt.figure(figsize=(14, 6))
x_pos = 0
xticks = []
xticklabels = []

for group, values in data.items():
    xs = list(range(x_pos, x_pos + len(values)))
    ys = list(values.values())

    # Scatter and line
    plt.scatter(xs, ys, label=group, color=colors[group], s=60)
    plt.plot(xs, ys, color=colors[group], linestyle='-', alpha=0.6)  # Line within group

    # X-axis labels
    xticks.extend(xs)
    xticklabels.extend(values.keys())
    x_pos += len(values)

plt.xticks(xticks, xticklabels, rotation=90)
plt.ylabel("CorrelationSimilarity")
plt.title("Scatter Plot of Correlation Similarity by Cluster Groups")
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(0.9, 1.02)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data grouped by category
data = {
    "Each cluster alone": {
        "min_0": 1.0,
        "min_1": 1.0,
        "min_2": 0.8357348703170029,
        "informative_cluster_0": 0.9556475458308693,
        "informative_cluster_1": 0.9686587801505607,
    },
    "Everything together": {
        "everything_together": 0.907085846585024,
    },
    "Each class together": {
        "df_min": 0.9929380250821868,
        "df_majority": 0.9523170731707318,
    },
    "Mixed clusters": {
        "min_0_informative_cluster_0": 0.9888416578108395,
        "min_0_informative_cluster_1": 0.9003249235474007,
        "min_1_informative_cluster_1": 0.9741842610364683,
        "min_1_informative_cluster_0": 0.9700107104605498,
        "min_2_informative_cluster_0": 0.9195289499509323,
        "min_2_informative_cluster_1": 0.9600350058343057,
        "min_0_min_1_informative_cluster_0_informative_cluster_1": 0.9251836175774929,
        "min_0_min_2_informative_cluster_0_informative_cluster_1": 0.9330507118860982,
        "min_1_min_2_informative_cluster_0_informative_cluster_1": 0.9723872210627709
    }
}


# Define colors for each group
colors = {
    "Each cluster alone": "royalblue",
    "Each class together": "green",
    "Everything together": "black",
    "Mixed clusters": "orange"
}

# Plotting
plt.figure(figsize=(14, 6))
x_pos = 0
xticks = []
xticklabels = []

for group, values in data.items():
    xs = list(range(x_pos, x_pos + len(values)))
    ys = list(values.values())

    # Scatter and line
    plt.scatter(xs, ys, label=group, color=colors[group], s=60)
    plt.plot(xs, ys, color=colors[group], linestyle='-', alpha=0.6)  # Line within group

    # X-axis labels
    xticks.extend(xs)
    xticklabels.extend(values.keys())
    x_pos += len(values)

plt.xticks(xticks, xticklabels, rotation=90)
plt.ylabel("CorrelationSimilarity")
plt.title("Scatter Plot of Correlation Similarity by Cluster Groups")
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(0.7, 1.2)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data grouped by category
data = {
    "Each cluster alone": {
        "min_0": 0.29570219169950035,
        "min_1": 0.07417768088579563,
        "min_2": 0.08696858557018994,
        "informative_cluster_0": 0.035160399933495415,
        "informative_cluster_1": 0.09974458790874109,
    },
    "Everything together": {
        "everything_together": 0.001826399455942299,
    },
    "Each class together": {
        "df_min": 0.0028982807629885535,
        "df_majority": 0.003173781414729576,
    },
    "Mixed clusters": {
        "min_0_informative_cluster_0": 0.03175558368342471,
        "min_0_informative_cluster_1": 0.011997589031625077,
        "min_1_informative_cluster_1": 0.014894614462013804,
        "min_1_informative_cluster_0": 0.01967817193059218,
        "min_2_informative_cluster_0": 0.019654511316558595,
        "min_2_informative_cluster_1": 0.0006817255309615392,
        "min_0_min_1_informative_cluster_0_informative_cluster_1": 0.005704315080208666,
        "min_0_min_2_informative_cluster_0_informative_cluster_1": 0.0017217224917579442,
        "min_1_min_2_informative_cluster_0_informative_cluster_1": 0.0014179871363931105
    }
}



# Define colors for each group
colors = {
    "Each cluster alone": "royalblue",
    "Each class together": "green",
    "Everything together": "black",
    "Mixed clusters": "orange"
}

# Plotting
plt.figure(figsize=(14, 6))
x_pos = 0
xticks = []
xticklabels = []

for group, values in data.items():
    xs = list(range(x_pos, x_pos + len(values)))
    ys = list(values.values())

    # Scatter and line
    plt.scatter(xs, ys, label=group, color=colors[group], s=60)
    plt.plot(xs, ys, color=colors[group], linestyle='-', alpha=0.6)  # Line within group

    # X-axis labels
    xticks.extend(xs)
    xticklabels.extend(values.keys())
    x_pos += len(values)

plt.xticks(xticks, xticklabels, rotation=90)
plt.ylabel("CorrelationSimilarity")
plt.title("Scatter Plot of Correlation Similarity by Cluster Groups")
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(0.0, 0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data grouped by category
data = {
    "Each cluster alone": {
        "min_0": 1,
        "min_1": 1,
        "min_2": 1,
        "informative_cluster_0": 1,
        "informative_cluster_1": 1,
    },
    "Everything together": {
        "everything_together": 1,
    },
    "Each class together": {
        "df_mindf_min": 1,
        "df_min": 1,
        "df_majority": 1,
    },
    "Mixed clusters": {
        "min_0_informative_cluster_0": 1,
        "min_0_informative_cluster_1": 1,
        "min_1_informative_cluster_1": 1,
        "min_1_informative_cluster_0": 1,
        "min_2_informative_cluster_0": 1,
        "min_2_informative_cluster_1": 1,
        "min_0_min_1_informative_cluster_0_informative_cluster_1": 1,
        "min_0_min_2_informative_cluster_0_informative_cluster_1": 1,
        "min_1_min_2_informative_cluster_0_informative_cluster_1": 1
    }
}




# Define colors for each group
colors = {
    "Each cluster alone": "royalblue",
    "Each class together": "green",
    "Everything together": "black",
    "Mixed clusters": "orange"
}

# Plotting
plt.figure(figsize=(14, 6))
x_pos = 0
xticks = []
xticklabels = []

for group, values in data.items():
    xs = list(range(x_pos, x_pos + len(values)))
    ys = list(values.values())

    # Scatter and line
    plt.scatter(xs, ys, label=group, color=colors[group], s=60)
    plt.plot(xs, ys, color=colors[group], linestyle='-', alpha=0.6)  # Line within group

    # X-axis labels
    xticks.extend(xs)
    xticklabels.extend(values.keys())
    x_pos += len(values)

plt.xticks(xticks, xticklabels, rotation=90)
plt.ylabel("CorrelationSimilarity")
plt.title("Scatter Plot of Correlation Similarity by Cluster Groups")
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(0.0, 1.5)
plt.legend()
plt.tight_layout()
plt.show()
